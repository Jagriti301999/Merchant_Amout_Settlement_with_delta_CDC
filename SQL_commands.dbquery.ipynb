-- %%
/*
select * from incremental_load.default.raw_upi_transactions_v1;
DESCRIBE DETAIL incremental_load.default.raw_upi_transactions_v1;

ALTER TABLE incremental_load.default.raw_upi_transactions_v1
SET TBLPROPERTIES (
  delta.enableChangeDataFeed = true
);

DESCRIBE DETAIL incremental_load.default.raw_upi_transactions_v1;

SHOW VOLUMES IN incremental_load.default;

*/
select * from incremental_load.default.raw_upi_transactions_v1;
